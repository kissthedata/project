# %%
import pandas as pd
import numpy as np
import seaborn as sns
from xml.etree import ElementTree as ET
import matplotlib.pyplot as plt

import re
# 한글 폰트 설정 (Mac)
plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['axes.unicode_minus'] = False  # 마이너스 기호 깨짐 방지

# %%
df
# Out:
#             기준일자 회사코드   보험사         상품군     구분                          상품명  \
# 0       20251013  N11  DB손보  4세대 실손의료보험     질병         다이렉트 실손의료비보험2510(CM)
# 1       20251013  N11  DB손보  4세대 실손의료보험  3대비급여         다이렉트 실손의료비보험2510(CM)
# 2       20251013  N11  DB손보  4세대 실손의료보험   상해급여         다이렉트 실손의료비보험2510(CM)
# 3       20251013  N11  DB손보  4세대 실손의료보험     질병         다이렉트 실손의료비보험2510(CM)
# 4       20251013  N11  DB손보  4세대 실손의료보험   질병급여         다이렉트 실손의료비보험2510(CM)
# ...          ...  ...   ...         ...    ...                          ...
# 250857  20210101  L42  null        유병력자     상해  NH유병력자실손의료비보험(갱신형,무배당)_2101
# 250858  20210101  L42  null        유병력자     상해  NH유병력자실손의료비보험(갱신형,무배당)_2101
# 250859  20210101  L42  null        유병력자     상해  NH유병력자실손의료비보험(갱신형,무배당)_2101
# 250860  20210101  L42  null        유병력자     상해  NH유병력자실손의료비보험(갱신형,무배당)_2101
# 250861  20210101  L42  null        유병력자  3대비급여  NH유병력자실손의료비보험(갱신형,무배당)_2101
#
#           성별  연령   보험료
# 0       None  46  None
# 1       None  60  None
# 2       None  22  None
# 3       None  42  None
# 4       None  42  None
# ...      ...  ..   ...
# 250857  None  39  None
# 250858  None  40  None
# 250859  None  41  None
# 250860  None  42  None
# 250861  None  22  None
#
# [250862 rows x 9 columns]
